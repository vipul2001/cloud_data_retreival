# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
channel=pd.read_csv("channel.csv")

# %%
channel.lat=channel.lat/1000
channel.log=channel.log/1000
channel
# Out:
#          Unnamed: 0  Unnamed: 0.1     lat     log  IMG_VIS  IMG_SWIR
# 0                 0      22176213  36.882  80.638      172       359
# 1                 1      22176214  36.882  80.649      171       367
# 2                 2      22176215  36.882  80.661      172       365
# 3                 3      22176216  36.882  80.673      171       359
# 4                 4      22176217  36.882  80.684      172       361
# ...             ...           ...     ...     ...      ...       ...
# 4875899     4875899      44008054  16.080  58.386      121       187
# 4875900     4875900      44008055  16.079  58.397      122       182
# 4875901     4875901      44008056  16.079  58.408      116       179
# 4875902     4875902      44008057  16.079  58.418      114       176
# 4875903     4875903      44008058  16.079  58.429      107       160
#
# [4875904 rows x 6 columns]

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#          Unnamed: 0     log     lat   cot   cer
# 0               546  72.139  36.137  1197  1059
# 1               615  72.913  36.030  1414  2046
# 2               633  73.109  36.002  1609  1249
# 3               634  73.120  36.000  1288  2440
# 4               635  73.131  35.999  1300  1409
# ...             ...     ...     ...   ...   ...
# 1482108     2747259  79.473  16.044   847   417
# 1482109     2747260  79.515  16.036   778   245
# 1482110     2747261  79.557  16.027  1424   219
# 1482111     2747262  79.600  16.018  1043   590
# 1482112     2747263  79.643  16.009   901   770
#
# [1482113 rows x 5 columns]

# %%
result = pd.merge(channel,data, how='left', on=['lat', 'log'])

# %%
result=result.dropna()
result
# Out:
#          Unnamed: 0_x  Unnamed: 0.1     lat     log  IMG_VIS  IMG_SWIR  \
# 173482         173482      23185462  35.805  74.312      104       220
# 200804         200804      23320102  35.655  74.329      348       360
# 209985         209985      23365040  35.594  75.006      345       383
# 237145         237145      23499437  35.494  72.200       87       229
# 255560         255560      23589310  35.369  73.528      362       398
# ...               ...           ...     ...     ...      ...       ...
# 4782321       4782321      43404227  16.334  78.757      452       443
# 4782419       4782419      43404325  16.331  79.685      316       414
# 4807288       4807288      43505274  16.245  79.393      214       367
# 4810059       4810059      43516498  16.235  79.431      127       282
# 4829384       4829384      43594987  16.169  78.950      191       312
#
#          Unnamed: 0_y     cot     cer
# 173482         3452.0  1652.0  2103.0
# ...

# %%
result.to_csv("map.csv")
